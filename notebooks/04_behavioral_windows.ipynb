# %% [markdown]
# # Behavioral Windows
# Inspect rolling window features and leakage-safe future labels.

# %%
import pandas as pd
features = pd.read_parquet('../features.parquet')
features[['rolling_20_reply_rate', 'rolling_7d_sender_share', 'next_reply_delay_bucket']].head()
