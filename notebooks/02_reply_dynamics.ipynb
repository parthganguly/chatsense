# %% [markdown]
# # Reply Dynamics
# Explore reply delay distributions by sender.

# %%
import pandas as pd
features = pd.read_parquet('../features.parquet')
features.dropna(subset=['reply_delay_min']).groupby('sender')['reply_delay_min'].describe()
