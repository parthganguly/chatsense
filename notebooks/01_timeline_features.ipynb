# %% [markdown]
# # Timeline Features
# Load `features.parquet` and inspect daily message activity.

# %%
import pandas as pd
features = pd.read_parquet('../features.parquet')
features.groupby(['date', 'sender']).size().reset_index(name='messages').head()
